# %%
# %load_ext uhed

# %%
SITE = VTSAM.Illinois
SLICE = "gautamrams"

# %%
# %slice gautamrams

# %%
# %site vts-illinois

# %%
SITE.deletesliver(context,SLICE)

# %%
# %lab

# %%
genish.showtopo(manifest , "dot")

# %%
genish.showtopo(manifest , "neato")

# %%
SITE.Host.getARPTable(context , SLICE , "host1")
# Out:
# <table>
# <tr><th>HW Address</th><th>IP Address</th><th>Status</th><th>Interface</th></tr>
# <tr><td>2e:b2:10:0a:56:d4</td><td>10.10.0.5</td><td>complete</td><td>eth1</td></tr>
# <table

# %% [markdown]
# ## Ping between host1 and host5  (same VLAN and the same L3)
#
# gramasam@cot-cn:~$ gssh gautamrams host1
# / # ping 10.10.0.5
# PING 10.10.0.5 (10.10.0.5) 56(84) bytes of data.
# 64 bytes from 10.10.0.5: icmp_seq=1 ttl=64 time=0.959 ms
# 64 bytes from 10.10.0.5: icmp_seq=2 ttl=64 time=0.105 ms
# 64 bytes from 10.10.0.5: icmp_seq=3 ttl=64 time=0.100 ms
# 64 bytes from 10.10.0.5: icmp_seq=4 ttl=64 time=0.099 ms
# 64 bytes from 10.10.0.5: icmp_seq=5 ttl=64 time=0.106 ms
# 64 bytes from 10.10.0.5: icmp_seq=6 ttl=64 time=0.103 ms
# 64 bytes from 10.10.0.5: icmp_seq=7 ttl=64 time=0.104 ms
# 64 bytes from 10.10.0.5: icmp_seq=8 ttl=64 time=0.103 ms
# 64 bytes from 10.10.0.5: icmp_seq=9 ttl=64 time=0.104 ms
# 64 bytes from 10.10.0.5: icmp_seq=10 ttl=64 time=0.101 ms
# 64 bytes from 10.10.0.5: icmp_seq=11 ttl=64 time=0.106 ms
# 64 bytes from 10.10.0.5: icmp_seq=12 ttl=64 time=0.125 ms
# 64 bytes from 10.10.0.5: icmp_seq=13 ttl=64 time=0.116 ms
# 64 bytes from 10.10.0.5: icmp_seq=14 ttl=64 time=0.114 ms
# 64 bytes from 10.10.0.5: icmp_seq=15 ttl=64 time=0.116 ms
# 64 bytes from 10.10.0.5: icmp_seq=16 ttl=64 time=0.116 ms
# 64 bytes from 10.10.0.5: icmp_seq=17 ttl=64 time=0.118 ms
# 64 bytes from 10.10.0.5: icmp_seq=18 ttl=64 time=0.116 ms
# 64 bytes from 10.10.0.5: icmp_seq=19 ttl=64 time=0.117 ms
# 64 bytes from 10.10.0.5: icmp_seq=20 ttl=64 time=0.113 ms
# 64 bytes from 10.10.0.5: icmp_seq=21 ttl=64 time=0.116 ms
# 64 bytes from 10.10.0.5: icmp_seq=22 ttl=64 time=0.114 ms
# 64 bytes from 10.10.0.5: icmp_seq=23 ttl=64 time=0.115 ms
# 64 bytes from 10.10.0.5: icmp_seq=24 ttl=64 time=0.115 ms
# 64 bytes from 10.10.0.5: icmp_seq=25 ttl=64 time=0.115 ms
# 64 bytes from 10.10.0.5: icmp_seq=26 ttl=64 time=0.116 ms
# 64 bytes from 10.10.0.5: icmp_seq=27 ttl=64 time=0.116 ms
# 64 bytes from 10.10.0.5: icmp_seq=28 ttl=64 time=0.113 ms
# 64 bytes from 10.10.0.5: icmp_seq=92 ttl=64 time=0.111 ms
# 64 bytes from 10.10.0.5: icmp_seq=93 ttl=64 time=0.112 ms
# 64 bytes from 10.10.0.5: icmp_seq=94 ttl=64 time=0.115 ms
# 64 bytes from 10.10.0.5: icmp_seq=95 ttl=64 time=0.111 ms
# 64 bytes from 10.10.0.5: icmp_seq=96 ttl=64 time=0.112 ms
# 64 bytes from 10.10.0.5: icmp_seq=97 ttl=64 time=0.110 ms
# 64 bytes from 10.10.0.5: icmp_seq=98 ttl=64 time=0.111 ms
# 64 bytes from 10.10.0.5: icmp_seq=99 ttl=64 time=0.110 ms
# 64 bytes from 10.10.0.5: icmp_seq=100 ttl=64 time=0.111 ms
# 64 bytes from 10.10.0.5: icmp_seq=101 ttl=64 time=0.157 ms
# 64 bytes from 10.10.0.5: icmp_seq=102 ttl=64 time=0.117 ms
# 64 bytes from 10.10.0.5: icmp_seq=103 ttl=64 time=0.115 ms
# 64 bytes from 10.10.0.5: icmp_seq=104 ttl=64 time=0.179 ms
# 64 bytes from 10.10.0.5: icmp_seq=105 ttl=64 time=0.109 ms
# 64 bytes from 10.10.0.5: icmp_seq=106 ttl=64 time=0.114 ms
# 64 bytes from 10.10.0.5: icmp_seq=107 ttl=64 time=0.114 ms
# 64 bytes from 10.10.0.5: icmp_seq=108 ttl=64 time=0.114 ms
# 64 bytes from 10.10.0.5: icmp_seq=109 ttl=64 time=0.113 ms
# 64 bytes from 10.10.0.5: icmp_seq=110 ttl=64 time=0.114 ms
# 64 bytes from 10.10.0.5: icmp_seq=111 ttl=64 time=0.111 ms
# 64 bytes from 10.10.0.5: icmp_seq=112 ttl=64 time=0.107 ms
# 64 bytes from 10.10.0.5: icmp_seq=113 ttl=64 time=0.109 ms
# 64 bytes from 10.10.0.5: icmp_seq=114 ttl=64 time=0.115 ms
# 64 bytes from 10.10.0.5: icmp_seq=115 ttl=64 time=0.117 ms
# 64 bytes from 10.10.0.5: icmp_seq=116 ttl=64 time=0.110 ms
# 64 bytes from 10.10.0.5: icmp_seq=117 ttl=64 time=0.111 ms
# ^C
# --- 10.10.0.5 ping statistics ---
# 117 packets transmitted, 117 received, 0% packet loss, time 115998ms
# rtt min/avg/max/mdev = 0.091/0.122/0.959/0.079 ms
# / #
# 64 bytes from 10.10.0.5: icmp_seq=29 ttl=64 time=0.116 ms
#
#
#
# gramasam@cot-cn:~$ gssh gautamrams host2
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# 23:03:05.673419 42:29:84:6a:43:41 (oui Unknown) > Broadcast, ethertype ARP (0x0806), length 42: Request who-has 10.10.0.5 tell 10.10.0.1, length
#  28
# ^C
# 1 packet captured
# 1 packet received by filter
# 0 packets dropped by kernel
# / #
#
# gramasam@cot-cn:~$ gssh gautamrams host3
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# ^C
# 0 packets captured
# 0 packets received by filter
# 0 packets dropped by kernel
# / #
#
#
# gramasam@cot-cn:~$ gssh gautamrams host4
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# 23:03:05.673422 42:29:84:6a:43:41 (oui Unknown) > Broadcast, ethertype ARP (0x0806), length 42: Request who-has 10.10.0.5 tell 10.10.0.1, length
#  28
# ^C
# 1 packet captured
# 1 packet received by filter
# 0 packets dropped by kernel
# / #
#
# gramasam@cot-cn:~$ gssh gautamrams host5
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# 23:03:05.673542 42:29:84:6a:43:41 (oui Unknown) > Broadcast, ethertype ARP (0x0806), length 42: Request who-has 10.10.0.5 tell 10.10.0.1, length
#  28
# 23:03:05.673577 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype ARP (0x0806), length 42: Reply 10.10.0.5 is-at 2e:b
# 2:10:0a:56:d4 (oui Unknown), length 28
# 23:03:05.673947 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 22, seq 1, length 64
# 23:03:05.674001 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 22, seq 1, length 64
# 23:03:06.674217 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 22, seq 2, length 64
# 23:03:06.674251 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 22, seq 2, length 64
# 23:03:07.673213 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 22, seq 3, length 64
# 23:03:16.671749 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 22, seq 12, length 64
# 23:03:16.671796 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 22, seq 12, length 64
# 23:03:17.671417 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 22, seq 13, length 64
# 23:03:17.671461 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 22, seq 13, length 64
# 23:03:18.671513 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 22, seq 14, length 64
# 23:03:18.671556 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 22, seq 14, length 64
# 23:03:19.671416 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 22, seq 15, length 64
# 23:04:59.671408 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 22, seq 115, length 64
# 23:04:59.671453 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 22, seq 115, length 64
# 23:05:00.671474 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 22, seq 116, length 64
# 23:05:00.671511 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 22, seq 116, length 64
# 23:05:01.671420 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 22, seq 117, length 64
# 23:05:01.671459 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 22, seq 117, length 64
# ^C
# 223 packets captured
# 242 packets received by filter
# 19 packets dropped by kernel
# / #
#
# gramasam@cot-cn:~$ gssh gautamrams host6
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# ^C
# 0 packets captured
# 0 packets received by filter
# 0 packets dropped by kernel
# / #
#
# gramasam@cot-cn:~$ gssh gautamrams host7
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# 23:03:05.673426 42:29:84:6a:43:41 (oui Unknown) > Broadcast, ethertype 802.1Q (0x8100), length 46: vlan 100, p 0, ethertype ARP, Request who-has
#  10.10.0.5 tell 10.10.0.1, length 28
# ^C
# 1 packet captured
# 1 packet received by filter
# 0 packets dropped by kernel
# / #

# %% [markdown]
# ## Why did you get the ping results you got ?
#
# The network has host1 and host5 in same VLAN and subnet . When we ping host5 from host1 ,
#
# 1) host5 is reachable hence it responds back with echo reply.
# 2) host2 and host4 broadcasts the ARP request as both are in same VLAN.
# 3) host7 also braodcasts the ARP request because it doesn't have any VLAN assigned to it.
# 4) host3 and host6 are in a different VLAN and different subnet. Hence they are unreachable.

# %% [markdown]
# ## ARP table for host1

# %%
SITE.Host.getARPTable(context , SLICE , "host1")
# Out:
# <table>
# <tr><th>HW Address</th><th>IP Address</th><th>Status</th><th>Interface</th></tr>
# <tr><td>2e:b2:10:0a:56:d4</td><td>10.10.0.5</td><td>complete</td><td>eth1</td></tr>
# <table

# %% [markdown]
# ## ARP observations
#
# gramasam@cot-cn:~$ gssh gautamrams host1
# / # ping 10.10.2.2
# connect: Network unreachable
# / # ping 10.10.0.5
# PING 10.10.0.5 (10.10.0.5) 56(84) bytes of data.
# 64 bytes from 10.10.0.5: icmp_seq=1 ttl=64 time=0.633 ms
# 64 bytes from 10.10.0.5: icmp_seq=2 ttl=64 time=0.104 ms
# 64 bytes from 10.10.0.5: icmp_seq=3 ttl=64 time=0.105 ms
# 64 bytes from 10.10.0.5: icmp_seq=4 ttl=64 time=0.106 ms
# 64 bytes from 10.10.0.5: icmp_seq=5 ttl=64 time=0.107 ms
# 64 bytes from 10.10.0.5: icmp_seq=6 ttl=64 time=0.104 ms
# 64 bytes from 10.10.0.5: icmp_seq=7 ttl=64 time=0.103 ms
# 64 bytes from 10.10.0.5: icmp_seq=8 ttl=64 time=0.104 ms
# 64 bytes from 10.10.0.5: icmp_seq=9 ttl=64 time=0.101 ms
# 64 bytes from 10.10.0.5: icmp_seq=10 ttl=64 time=0.103 ms
# ^C
# --- 10.10.0.5 ping statistics ---
# 10 packets transmitted, 10 received, 0% packet loss, time 9000ms
# rtt min/avg/max/mdev = 0.101/0.157/0.633/0.158 ms
# / # ping 10.10.2.7
# connect: Network unreachable
# / # ping 10.10.3.3
# connect: Network unreachable
# / # ping 10.10.3.6
# connect: Network unreachable
# / # ping 10.10.2.4
# connect: Network unreachable
# / #
#
#
# gramasam@cot-cn:~$ gssh gautamrams host2
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# 23:39:04.431392 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 31, seq 1, length 64
# ^C
# 1 packet captured
# 1 packet received by filter
# 0 packets dropped by kernel
# / #
#
# gramasam@cot-cn:~$ gssh gautamrams host3
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# ^C
# 0 packets captured
# 0 packets received by filter
# 0 packets dropped by kernel
# / #
#
# gramasam@cot-cn:~$ gssh gautamrams host4
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# 23:39:04.431395 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 31, seq 1, length 64
# ^C
# 1 packet captured
# 1 packet received by filter
# 0 packets dropped by kernel
# / #
#
# gramasam@cot-cn:~$ gssh gautamrams host5
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# 23:39:04.431524 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 31, seq 1, length 64
# 23:39:04.431591 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 31, seq 1, length 64
# 23:39:05.431413 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 31, seq 2, length 64
# 23:39:05.431446 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 31, seq 2, length 64
# 23:39:06.431420 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 31, seq 3, length 64
# 23:39:06.431453 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 31, seq 3, length 64
# 23:39:07.431423 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 31, seq 4, length 64
# ^C
# 7 packets captured
# 22 packets received by filter
# 15 packets dropped by kernel
# / #
#
# gramasam@cot-cn:~$ gssh gautamrams host6
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# ^C
# 0 packets captured
# 0 packets received by filter
# 0 packets dropped by kernel
# / #
#
#
# gramasam@cot-cn:~$ gssh gautamrams host7
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# 23:39:04.431399 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype 802.1Q (0x8100), length 102: vlan 100, p 0, etherty
# pe IPv4, 10.10.0.1 > 10.10.0.5: ICMP echo request, id 31, seq 1, length 64
# ^C
# 1 packet captured
# 1 packet received by filter
# 0 packets dropped by kernel
# / #

# %% [markdown]
# ## ARP request and reply from host5
#
# gramasam@cot-cn:~$ gssh gautamrams host5
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# 23:39:04.431524 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 31, seq 1, length 64
# 23:39:04.431591 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 31, seq 1, length 64
# 23:39:05.431413 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 31, seq 2, length 64
# 23:39:05.431446 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 31, seq 2, length 64
# 23:39:06.431420 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 31, seq 3, length 64
# 23:39:06.431453 2e:b2:10:0a:56:d4 (oui Unknown) > 42:29:84:6a:43:41 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 31, seq 3, length 64
# 23:39:07.431423 42:29:84:6a:43:41 (oui Unknown) > 2e:b2:10:0a:56:d4 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 31, seq 4, length 64
# ^C
# 7 packets captured
# 22 packets received by filter
# 15 packets dropped by kernel
# / #

# %% [markdown]
# ###  sample ARP messages
#
# Pinging host5 from host1
# / # ping 10.10.0.5
# PING 10.10.0.5 (10.10.0.5) 56(84) bytes of data.
# 64 bytes from 10.10.0.5: icmp_seq=1 ttl=64 time=1.69 ms
# 64 bytes from 10.10.0.5: icmp_seq=2 ttl=64 time=0.113 ms
# 64 bytes from 10.10.0.5: icmp_seq=3 ttl=64 time=0.083 ms
# 64 bytes from 10.10.0.5: icmp_seq=4 ttl=64 time=0.107 ms
# 64 bytes from 10.10.0.5: icmp_seq=5 ttl=64 time=0.117 ms
# 64 bytes from 10.10.0.5: icmp_seq=6 ttl=64 time=0.119 ms
# 64 bytes from 10.10.0.5: icmp_seq=7 ttl=64 time=0.436 ms
# 64 bytes from 10.10.0.5: icmp_seq=8 ttl=64 time=0.096 ms
# 64 bytes from 10.10.0.5: icmp_seq=9 ttl=64 time=0.084 ms
# 64 bytes from 10.10.0.5: icmp_seq=10 ttl=64 time=0.118 ms
# ^C
# --- 10.10.0.5 ping statistics ---
# 10 packets transmitted, 10 received, 0% packet loss, time 8998ms
# rtt min/avg/max/mdev = 0.083/0.296/1.694/0.476 ms
#
# #### ARP request at host5
# / # tcpdump -i eth1 -e not ether dst 01:80:c2:00:00:00
# tcpdump: verbose output suppressed, use -v or -vv for full protocol decode
# listening on eth1, link-type EN10MB (Ethernet), capture size 262144 bytes
# 04:50:21.050825 32:be:a1:cd:6d:a7 (oui Unknown) > Broadcast, ethertype ARP (0x0806), length 42: Request who-has 10.10.0.5 tell 10.10.0.1, length 28
#
# #### ARP reply from host5
#
# 04:50:21.050852 5e:92:b9:93:51:f3 (oui Unknown) > 32:  be:a1:cd:6d:a7 (oui Unknown), ethertype ARP (0x0806), length 42: Reply 10.10.0.5 is-at 5e:9
# 2:b9:93:51:f3 (oui Unknown), length 28
# 04:50:21.051728 32:be:a1:cd:6d:a7 (oui Unknown) > 5e:92:b9:93:51:f3 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 17, seq 1, length 64
# 04:50:21.051797 5e:92:b9:93:51:f3 (oui Unknown) > 32:be:a1:cd:6d:a7 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 17, seq 1, length 64
# 04:50:22.052225 32:be:a1:cd:6d:a7 (oui Unknown) > 5e:92:b9:93:51:f3 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 17, seq 2, length 64
# 04:50:22.052259 5e:92:b9:93:51:f3 (oui Unknown) > 32:be:a1:cd:6d:a7 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.5 > 10.10.0.1: IC
# MP echo reply, id 17, seq 2, length 64
# 04:50:23.051207 32:be:a1:cd:6d:a7 (oui Unknown) > 5e:92:b9:93:51:f3 (oui Unknown), ethertype IPv4 (0x0800), length 98: 10.10.0.1 > 10.10.0.5: IC
# MP echo request, id 17, seq 3, length 64

# %% [markdown]
# ## What is ARP and what does it do ?
#
# ARP stands for Address Resolution Protocol. When you try to ping an IP address on your local network, say 192.168.1.1, your system has to turn the IP address 192.168.1.1 into a MAC address. The primary purpose of ARP is to resolve the address, hence its name.Systems keep an ARP look-up table where they store information about what IP addresses are associated with what MAC addresses. When trying to send a packet to an IP address, the system will first consult this table to see if it already knows the MAC address.If the IP address is not found in the ARP table, the system will then send a broadcast packet to the network using the ARP protocol to ask "who has 192.168.1.1". Because it is a broadcast packet, it is sent to a special MAC address that causes all machines on the network to receive it. Any machine with the requested IP address will reply with an ARP packet that says "I am 192.168.1.1", and this includes the MAC address which can receive packets for that IP.
